# %%
import sys
from pathlib import Path

SRC_DIR = Path.cwd().parent / "src"

if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

# %%
from vista.intake import create_variant
# Out:
# variant.py loaded

# %%
variant = create_variant(
    gene="PLIN4",
    hgvs="c.3702+5G>A",
    transcript="NM_001367868.2",
    classification="VUS",
    zygosity="Heterozygous",
    phenotype="Myopathy"
)

variant
# Out:
# Variant(gene='PLIN4', hgvs='c.3702+5G>A', transcript='NM_001367868.2', classification='VUS', zygosity='Heterozygous', phenotype='Myopathy', clinvar={}, gnomad={}, predictions={}, pubmed=[], acmg={}, report={})
