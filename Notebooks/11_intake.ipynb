# %%
import sys
from pathlib import Path

SRC_DIR = Path.cwd().parent / "src"

if str(SRC_DIR) not in sys.path:
    sys.path.insert(0, str(SRC_DIR))

# %%
import dev_setup

# %%
from vista.variant import Variant
from vista.intake import create_variant
# Out:
# variant.py loaded

# %%
import vista.intake

print(vista.intake.__file__)
# Out:
# /Users/samchirayil/Desktop/VISTA/src/vista/intake.py

# %%
print(dir(vista.intake))
# Out:
# ['Variant', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__spec__', 'create_variant']

# %%
from vista.intake import create_variant

variant = create_variant(
    gene="PLIN4",
    transcript="NM_001367868.2",
    hgvs="c.3702+5G>A",
    classification="VUS",
    zygosity="Heterozygous",
    phenotype="Myopathy with rimmed ubiquitin-positive autophagic vacuolation",
    inheritance="Autosomal dominant",
)

variant
# Out:
# Variant(gene='PLIN4', hgvs='c.3702+5G>A', transcript='NM_001367868.2', classification='VUS', zygosity='Heterozygous', phenotype='Myopathy with rimmed ubiquitin-positive autophagic vacuolation', inheritance='Autosomal dominant', clinvar={}, gnomad={}, predictions={}, pubmed=[], acmg={}, report={})

# %%
from pathlib import Path

print(Path.cwd())
# Out:
# /Users/samchirayil/Desktop/VISTA/Notebooks

# %%
import sys

for p in sys.path:
    print(p)
# Out:
# /Users/samchirayil/Desktop/VISTA/src
# /Users/samchirayil/Desktop/VISTA
# /opt/homebrew/Cellar/python@3.13/3.13.5/Frameworks/Python.framework/Versions/3.13/lib/python313.zip
# /opt/homebrew/Cellar/python@3.13/3.13.5/Frameworks/Python.framework/Versions/3.13/lib/python3.13
# /opt/homebrew/Cellar/python@3.13/3.13.5/Frameworks/Python.framework/Versions/3.13/lib/python3.13/lib-dynload
#
# /Users/samchirayil/Desktop/VISTA/.venv/lib/python3.13/site-packages

# %%
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd().parent

if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

print("Project Root:", PROJECT_ROOT)
print("\nCurrent sys.path:\n")

for p in sys.path:
    print(p)
# Out:
# Project Root: /Users/samchirayil/Desktop/VISTA
#
# Current sys.path:
#
# /Users/samchirayil/Desktop/VISTA/src
# /Users/samchirayil/Desktop/VISTA
# /opt/homebrew/Cellar/python@3.13/3.13.5/Frameworks/Python.framework/Versions/3.13/lib/python313.zip
# /opt/homebrew/Cellar/python@3.13/3.13.5/Frameworks/Python.framework/Versions/3.13/lib/python3.13
# /opt/homebrew/Cellar/python@3.13/3.13.5/Frameworks/Python.framework/Versions/3.13/lib/python3.13/lib-dynload
#
# /Users/samchirayil/Desktop/VISTA/.venv/lib/python3.13/site-packages

# %%
from vista.intake import create_variant

# %%
variant = create_variant(
    gene="PLIN4",
    transcript="NM_001367868.2",
    hgvs="c.3702+5G>A",
    classification="VUS",
    zygosity="Heterozygous",
    phenotype="Myopathy with rimmed ubiquitin-positive autophagic vacuolation",
    inheritance="Autosomal dominant",
)

variant
# Out:
# Variant(gene='PLIN4', hgvs='c.3702+5G>A', transcript='NM_001367868.2', classification='VUS', zygosity='Heterozygous', phenotype='Myopathy with rimmed ubiquitin-positive autophagic vacuolation', inheritance='Autosomal dominant', clinvar={}, gnomad={}, predictions={}, pubmed=[], acmg={}, report={})

# %%
import sys

print(sys.executable)
# Out:
# /Users/samchirayil/Desktop/VISTA/.venv/bin/python

# %%
import site

print(site.getsitepackages())
# Out:
# ['/Users/samchirayil/Desktop/VISTA/.venv/lib/python3.13/site-packages']

# %%
import vista
print(vista.__file__)
# Out:
# /Users/samchirayil/Desktop/VISTA/src/vista/__init__.py
