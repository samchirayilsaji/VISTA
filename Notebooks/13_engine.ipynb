# %%
import sys
from pathlib import Path

project_root = Path.cwd().parent
src_path = project_root / "src"

if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

# %%
from pprint import pprint

from vista.engine import VistaEngine

# %%
engine = VistaEngine()

# %%
report = engine.analyze(
    gene="PLIN4",
    transcript="NM_001367868.2",
    hgvs="c.3702+5G>A",
    classification="VUS",
    zygosity="Heterozygous",
    phenotype="Myopathy",
    inheritance="Autosomal dominant",
)
# Out:
# [{'seq_region_name': '19', 'strand': 1, 'end': 4508763, 'start': 4508763, 'id': 'rs1293047883', 'allele_string': 'C/T', 'frequencies': {'A': {'gnomade': 3.519e-06, 'gnomade_mid': 0, 'gnomade_amr': 0, 'gnomade_remaining': 0, 'gnomade_sas': 0, 'gnomade_eas': 0, 'gnomade_fin': 0, 'gnomade_asj': 0, 'gnomade_afr': 0, 'gnomade_nfe': 4.578e-06}}}]
# {'gnomade': 3.519e-06, 'gnomade_mid': 0, 'gnomade_amr': 0, 'gnomade_remaining': 0, 'gnomade_sas': 0, 'gnomade_eas': 0, 'gnomade_fin': 0, 'gnomade_asj': 0, 'gnomade_afr': 0, 'gnomade_nfe': 4.578e-06}

# %%
pprint(report)
# Out:
# {'acmg': {'BA1': {'code': 'BA1',
#                   'reason': 'Population frequency 0.00000 < 5%',
#                   'strength': 'Stand-alone',
#                   'triggered': False},
#           'BS1': {'code': 'BS1',
#                   'reason': 'Population frequency 0.00000',
#                   'strength': 'Strong',
#                   'triggered': False},
#           'PM2': {'code': 'PM2',
#                   'reason': 'Population frequency 0.00000',
#                   'strength': 'Moderate',
#                   'triggered': True},
#           'PVS1': {'code': 'PVS1',
#                    'reason': 'Variant is not at a canonical splice site',
#                    'strength': 'Very Strong',
#                    'triggered': False}},
#  'classification': {'label': 'VUS', 'score': 2},
#  'clinical': {'clinvar': {'found': False,
#                           'query': 'PLIN4[gene] AND c.3702+5G>A',
#                           'records': []},
#               'pubmed': {'count': 10,
#                          'papers': [{'authors': ['Haddix SG',
#                                                  'Zhang C',
#                                                  'Liu Y',
#                                                  'Oses-Prieto J',
#                                                  'Burlingame AL',
#                                                  'Rasband MN'],
#                                      'journal': 'Nature communications',
#                                      'pmid': '42168231',
#                                      'title': 'The perijunctional zone is a '
#                                               'molecularly distinct muscle '
#                                               'subdomain altered in Duchenne '
#                                               'muscular dystrophy.',
#                                      'year': '2026 May 21'},
#                                     {'authors': ['Carnazzi A',
#                                                  'Iannibelli E',
#                                                  'Gibertini S',
#                                                  'Nicolini De Gaetano L',
#                                                  'Riolo G',
#                                                  'Salerno F',
#                                                  'Legati A',
#                                                  'Ghezzi D',
#                                                  'Maggi L',
#                                                  'Ruggieri A'],
#                                      'journal': 'Genes & diseases',
#                                      'pmid': '41624901',
#                                      'title': 'Genetic variability in the '
#                                               'PLIN4 gene: A new sequence '
#                                               'duplication causing autophagic '
#                                               'vacuolar myopathy.',
#                                      'year': '2026 May'},
#                                     {'authors': ['Llansó L',
#                                                  'Stevanovski I',
#                                                  'Morís G',
#                                                  'Collet-Vidiella R',
#                                                  'Segarra-Casas A',
#                                                  'González-Quereda L',
#                                                  'Rodríguez-Santiago B',
#                                                  'Gallano P',
#                                                  'Alvarez R',
#                                                  'Vesperinas A',
#                                                  'Blanco R',
#                                                  'San-Millán B',
#                                                  'Navarro C',
#                                                  'Illa I',
#                                                  'Ravenscroft G',
#                                                  'Deveson IW',
#                                                  'Gallardo E',
#                                                  'Olivé M'],
#                                      'journal': 'Annals of clinical and '
#                                                 'translational neurology',
#                                      'pmid': '40693562',
#                                      'title': 'Repeat Expansions in PLIN4 '
#                                               'Cause Autosomal Dominant '
#                                               'Vacuolar Myopathy With '
#                                               'Sarcolemmal Features.',
#                                      'year': '2025 Oct'},
#                                     {'authors': ['Boivin M', 'Ravenscroft G'],
#                                      'journal': 'Current opinion in neurology',
#                                      'pmid': '40488265',
#                                      'title': 'Current understanding of '
#                                               'skeletal muscle repeat '
#                                               'expansion disorders.',
#                                      'year': '2025 Oct 1'},
#                                     {'authors': ['Yang K',
#                                                  'Liu Y',
#                                                  'Zhang J',
#                                                  'Yu Q',
#                                                  'Xu F',
#                                                  'Liu J',
#                                                  'Li Y',
#                                                  'Zhang X',
#                                                  'Wang Z',
#                                                  'Wang N',
#                                                  'Li Y',
#                                                  'Shi Y',
#                                                  'Chen WJ'],
#                                      'journal': 'Clinical chemistry',
#                                      'pmid': '39492694',
#                                      'title': 'dmTGS: Precise Targeted '
#                                               'Enrichment Long-Read Sequencing '
#                                               'Panel for Tandem Repeat '
#                                               'Detection.',
#                                      'year': '2025 Feb 3'},
#                                     {'authors': ['Bortolani S',
#                                                  'Savarese M',
#                                                  'Vattemi G',
#                                                  'Bonanno S',
#                                                  'Falzone YM',
#                                                  'Pugliese A',
#                                                  'Primiano G',
#                                                  'Sancricca C',
#                                                  'Lopergolo D',
#                                                  'Greco G',
#                                                  'Gemelli C',
#                                                  'Ravaglia S',
#                                                  'Bencivenga RP',
#                                                  'Velardo D',
#                                                  'Magri F',
#                                                  'Valentino ML',
#                                                  'Cheli M',
#                                                  'Torchia E',
#                                                  'Lucchini M',
#                                                  'Petrucci A',
#                                                  'Ricci G',
#                                                  'Garibaldi M',
#                                                  'Astrea G',
#                                                  'Rubegni A',
#                                                  'Angelini CI',
#                                                  'Ariatti A',
#                                                  'Santorelli FM',
#                                                  'Ruggieri A',
#                                                  'Antonini G',
#                                                  'Siciliano G',
#                                                  'Filosto M',
#                                                  'Mirabella M',
#                                                  'Liguori R',
#                                                  'Comi GP',
#                                                  'Ruggiero L',
#                                                  'Grandis M',
#                                                  'Massa R',
#                                                  'Malandrini A',
#                                                  'Servidei S',
#                                                  'Mongini TE',
#                                                  'Rodolico C',
#                                                  'Toscano A',
#                                                  'Previtali SC',
#                                                  'Tonin P',
#                                                  'Diaz-Manera J',
#                                                  'Monforte M',
#                                                  'Ricci E',
#                                                  'Maggi L',
#                                                  'Tasca G'],
#                                      'journal': 'Neurology',
#                                      'pmid': '39102614',
#                                      'title': 'Clinical, Histopathologic, and '
#                                               'Genetic Features of Patients '
#                                               'With Myofibrillary and Distal '
#                                               'Myopathies: Experience From the '
#                                               'Italian Network.',
#                                      'year': '2024 Aug 27'},
#                                     {'authors': ['Owusu R', 'Savarese M'],
#                                      'journal': 'Acta myologica : myopathies '
#                                                 'and cardiomyopathies : '
#                                                 'official journal of the '
#                                                 'Mediterranean Society of '
#                                                 'Myology',
#                                      'pmid': '38406378',
#                                      'title': 'Long-read sequencing improves '
#                                               'diagnostic rate in '
#                                               'neuromuscular disorders.',
#                                      'year': '2023'},
#                                     {'authors': ['Maggi L',
#                                                  'Gibertini S',
#                                                  'Iannibelli E',
#                                                  'Gallone A',
#                                                  'Bonanno S',
#                                                  'Cazzato D',
#                                                  'Gerevini S',
#                                                  'Moscatelli M',
#                                                  'Blasevich F',
#                                                  'Riolo G',
#                                                  'Mantegazza R',
#                                                  'Ruggieri A'],
#                                      'journal': 'Journal of neurology',
#                                      'pmid': '37145156',
#                                      'title': 'PLIN4-related myopathy: '
#                                               'clinical, histological and '
#                                               'imaging data in a large cohort '
#                                               'of patients.',
#                                      'year': '2023 Sep'},
#                                     {'authors': ['Wang Q',
#                                                  'Yu M',
#                                                  'Zhang W',
#                                                  'Gang Q',
#                                                  'Xie Z',
#                                                  'Xu J',
#                                                  'Zhou C',
#                                                  'Wang D',
#                                                  'Meng L',
#                                                  'Lv H',
#                                                  'Jia Z',
#                                                  'Deng J',
#                                                  'Yuan Y',
#                                                  'Wang Z'],
#                                      'journal': 'Annals of clinical and '
#                                                 'translational neurology',
#                                      'pmid': '36151849',
#                                      'title': 'Subsarcolemmal and cytoplasmic '
#                                               'p62 positivity and rimmed '
#                                               'vacuoles are distinctive for '
#                                               'PLIN4-myopathy.',
#                                      'year': '2022 Nov'},
#                                     {'authors': ['Yang K',
#                                                  'Zeng YH',
#                                                  'Qiu YS',
#                                                  'Lin F',
#                                                  'Chen HZ',
#                                                  'Jin M',
#                                                  'Chen L',
#                                                  'Zheng FZ',
#                                                  'Ding YL',
#                                                  'Cao CY',
#                                                  'Lin MT',
#                                                  'Chen WJ',
#                                                  'Wang ZQ',
#                                                  'Wang N'],
#                                      'journal': 'Acta neuropathologica',
#                                      'pmid': '35499779',
#                                      'title': 'Expanding the phenotype and '
#                                               'genotype spectra of '
#                                               'PLIN4-associated myopathy with '
#                                               'rimmed ubiquitin-positive '
#                                               'autophagic vacuolation.',
#                                      'year': '2022 Jun'}]}},
#  'coordinates': {'alt': 'A',
#                  'chromosome': '19',
#                  'genome_build': 'GRCh38',
#                  'position': 4508763,
#                  'ref': 'G'},
#  'metadata': {'generated_at': '2026-07-09T11:35:12.533936',
#               'vista_version': '0.1.0'},
#  'population': {'gnomad': {'gnomade': 3.519e-06,
#                            'gnomade_afr': 0,
#                            'gnomade_amr': 0,
#                            'gnomade_asj': 0,
#                            'gnomade_eas': 0,
#                            'gnomade_fin': 0,
#                            'gnomade_mid': 0,
#                            'gnomade_nfe': 4.578e-06,
#                            'gnomade_remaining': 0,
#                            'gnomade_sas': 0}},
#  'variant': {'gene': 'PLIN4',
#              'hgvs': 'c.3702+5G>A',
#              'inheritance': 'Autosomal dominant',
#              'phenotype': 'Myopathy',
#              'transcript': 'NM_001367868.2',
#              'zygosity': 'Heterozygous'}}
